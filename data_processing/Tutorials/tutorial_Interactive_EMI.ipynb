# %% [markdown]
# # Interactive Forward Modeller EMI
# This notebook shows how to use the `InteractiveForwardEMI` class.
# ### Imports
# Start with the following import:

# %%
from gp_tools.emi import InteractiveForwardEMI

# %% [markdown]
# ### Error: no module emagpy
# Should you get the above error message, change to the terminal and run the command `pip install emagpy`. Then restart the Notebook and everything should work.

# %% [markdown]
# ### Initialisation
# After importing the `InteractiveForwardEMI`-class, you need to create an instance of it by assigning the class a name. A sample name is seen in the cell below. In order to start using the Interface, the method `.start()` is called. Now the User-Interface should appear below.
#
# ### Using the UI
# In the UI, you can select the thickness and conductivity of each layer, add layers and substract them. Additionally you can save for each state the image, the depth and resistivities model or the response (as a csv file for interoperability with existing inversion algorithms). You can also save all of them.
#
# ### Error: Too many images just loaded
# Should you load a model and more than one image loads, please click the `Refresh`-Button. This is a bug from a module we use, an could not be fixed within the class.
#
# ### More Information
# Should you be curious, you can look through the `interactive_EMI.py` file. It is not fully documented but written rather legibly, so you might gain some insight.
#
# Best of luck, and have fun doing science!

# %%
IE = InteractiveForwardEMI()
IE.start()
IE.author = 'Test Author' #your name here
IE.project_name = 'Test Project' #your group name here

# %%
IE.layer_number = 3
IE.memis_nr = 6
IE.cmd_mini_nr = 3
IE.cmd_expl_nr = 3
IE.update()
# Out:
# ...
# Forward modelling
# Forward modelling
# C:\Users\peter\Documents\02_coding\02_Geophysics\geophysics_repo\src\gp_tools\emi\interactive_EMI.py:487: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   value = df_results.iloc[0][i][0]
# Forward modelling
# Forward modelling
# C:\Users\peter\Documents\02_coding\02_Geophysics\geophysics_repo\src\gp_tools\emi\interactive_EMI.py:487: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   value = df_results.iloc[0][i][0]
# Forward modelling
# Forward modelling
# ...
